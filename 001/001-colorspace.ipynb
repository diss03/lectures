# %% [markdown]
# # Цветовые пространства

# %% [markdown]
# ## Загрузка изображения из файла

# %%
import cv2

# %%
img = cv2.imread('/home/pic.png', cv2.IMREAD_COLOR)

# %%
print('type: ', type(img))
print('shape: ', img.shape)
# Out:
# type:  <class 'numpy.ndarray'>
# shape:  (512, 512, 3)

# %% [markdown]
# ## Визуализация в matplotlib

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.imshow(img[:,:,::-1])
plt.imshow(img[...,::-1])

# %%
# изменяем порядок каналов для визуализации (b, g, r) -> (r, g, b)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## Переходим в пространство цветов HSV

# %%
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
plt.figure(1, figsize = (16, 4))
plt.subplot(141)
plt.imshow(img[...,::-1])
plt.subplot(142)
plt.imshow(img_hsv[...,0]/179, cmap='gray')
plt.title('Hue')
plt.subplot(143)
plt.imshow(img_hsv[...,1], cmap='gray')
plt.title('Saturation')
plt.subplot(144)
plt.imshow(img_hsv[...,2], cmap='gray')
plt.title('Value');

# %%
plt.imshow(img_hsv)

# %%
max(img_hsv[:,:,1].flatten())
# Out:
# np.uint8(246)

# %%
max(img_hsv[:,:,2].flatten())
# Out:
# np.uint8(255)

# %%
max(img_hsv[:,:,0].flatten())
# Out:
# np.uint8(179)

# %%
hsv_normalized = img_hsv / [179, 255, 255]
plt.imshow(hsv_normalized)
